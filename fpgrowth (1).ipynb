# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

# Any results you write to the current directory are saved as output.

# %%
df = pd.read_csv('groceries - groceries.csv')

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
items = (df['Item 1'].unique())

# %%
encoded_vals = []
for index, row in df.iterrows():
    labels = {}
    uncommons = list(set(items) - set(row))
    commons = list(set(items).intersection(row))
    for uc in uncommons:
        labels[uc] = 0
    for com in commons:
        labels[com] = 1
    encoded_vals.append(labels)
encoded_vals[0]
ohe_df = pd.DataFrame(encoded_vals)

# %%
freq_items = fpgrowth(ohe_df, min_support=0.02, use_colnames=True)
freq_items.head()
# Out:
# C:\Users\Pranav\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support          itemsets
# 0  0.082766    (citrus fruit)
# 1  0.058566       (margarine)
# 2  0.139502          (yogurt)
# 3  0.104931  (tropical fruit)
# 4  0.058058          (coffee)

# %%
rules = association_rules(freq_items, metric="confidence", min_threshold=0.1)
rules.head(5)
# Out:
#           antecedents     consequents  antecedent support  consequent support  \
# 0        (whole milk)  (citrus fruit)            0.255516            0.082766
# 1      (citrus fruit)    (whole milk)            0.082766            0.255516
# 2      (citrus fruit)        (yogurt)            0.082766            0.139502
# 3            (yogurt)  (citrus fruit)            0.139502            0.082766
# 4  (other vegetables)  (citrus fruit)            0.193493            0.082766
#
#     support  confidence      lift  leverage  conviction
# 0  0.030503    0.119379  1.442377  0.009355    1.041577
# 1  0.030503    0.368550  1.442377  0.009355    1.179008
# 2  0.021657    0.261671  1.875752  0.010111    1.165467
# 3  0.021657    0.155248  1.875752  0.010111    1.085803
# 4  0.028876    0.149238  1.803140  0.012862    1.078133

# %%
sr=[]
for row in rules.itertuples():
    if(len(getattr(row,'antecedents'))==2):
        sr.append(getattr(row,'Index'))
rules.iloc[sr].sort_values(by=['confidence'],ascending=False)
# Out:
#                             antecedents         consequents  \
# 17           (other vegetables, yogurt)        (whole milk)
# 92  (root vegetables, other vegetables)        (whole milk)
# 91        (whole milk, root vegetables)  (other vegetables)
# 16                 (whole milk, yogurt)  (other vegetables)
# 93       (whole milk, other vegetables)   (root vegetables)
# 15       (whole milk, other vegetables)            (yogurt)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 17            0.043416            0.255516  0.022267    0.512881  2.007235
# 92            0.047382            0.255516  0.023183    0.489270  1.914833
# 91            0.048907            0.193493  0.023183    0.474012  2.449770
# 16            0.056024            0.193493  0.022267    0.397459  2.054131
# 93            0.074835            0.108998  0.023183    0.309783  2.842082
# 15            0.074835            0.139502  0.022267    0.297554  2.132979
#
#     leverage  conviction
# 17  0.011174    1.528340
# 92  0.011076    1.457687
# 91  0.013719    1.533320
# 16  0.011427    1.338511
# 93  0.015026    1.290900
# 15  0.011828    1.225003
